# %% [markdown]
# 4.1

# %%
import pandas as pd

# %%
weather = pd.read_csv("../datasets/nyc_boston_weather.csv", index_col=0)

print(list(weather.nyc))
# Out:
# [93, 89, 88, 86, 87, 84, 81, 83, 83, 81, 83, 89, 90, 90, 85, 83, 84, 88, 92, 96, 97, 94, 97, 97, 89, 82, 86, 87, 87, 88, 87]

# %% [markdown]
# 4.1.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

m, sd = 63.5, 2.5
dist = np.random.normal(loc=m, scale=sd, size=25000)

sns.histplot(dist, bins=100, color="white")
plt.axvline(np.mean(dist), color="black", linestyle = "dotted")
plt.title(f"Normal Distribution with Mean {m} and Standard Deviation {sd}")
# Out:
# Text(0.5, 1.0, 'Normal Distribution with Mean 63.5 and Standard Deviation 2.5')

# %% [markdown]
# 4.1.3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dist = pd.Series(np.sqrt(np.random.exponential(1,75000)))
plt.hist(dist, bins = 100)
# Out:
# (array([1.430e+02, 3.340e+02, 5.190e+02, 7.320e+02, 9.020e+02, 1.063e+03,
#         1.295e+03, 1.362e+03, 1.563e+03, 1.705e+03, 1.842e+03, 1.988e+03,
#         2.076e+03, 2.181e+03, 2.198e+03, 2.314e+03, 2.308e+03, 2.291e+03,
#         2.372e+03, 2.366e+03, 2.341e+03, 2.272e+03, 2.267e+03, 2.310e+03,
#         2.260e+03, 2.167e+03, 2.113e+03, 1.912e+03, 1.983e+03, 1.835e+03,
#         1.709e+03, 1.625e+03, 1.522e+03, 1.416e+03, 1.320e+03, 1.245e+03,
#         1.269e+03, 1.141e+03, 1.043e+03, 9.300e+02, 8.820e+02, 8.200e+02,
#         7.770e+02, 6.790e+02, 6.090e+02, 5.480e+02, 5.290e+02, 4.420e+02,
#         4.220e+02, 3.840e+02, 3.450e+02, 2.990e+02, 2.830e+02, 2.360e+02,
#         2.020e+02, 1.780e+02, 1.720e+02, 1.300e+02, 1.300e+02, 1.050e+02,
#         8.900e+01, 7.300e+01, 7.200e+01, 5.500e+01, 4.000e+01, 3.800e+01,
#         3.600e+01, 2.800e+01, 2.700e+01, 2.400e+01, 1.700e+01, 1.900e+01,
#         1.100e+01, 1.200e+01, 1.000e+01, 5.000e+00, 8.000e+00, 4.000e+00,
#         4.000e+00, 3.000e+00, 4.000e+00, 1.000e+00, 1.000e+00, 2.000e+00,
#         1.000e+00, 3.000e+00, 0.000e+00, 1.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.00538887, 0.04183838, 0.07828789, 0.1147374 , 0.15118691,
#         0.18763642, 0.22408593, 0.26053544, 0.29698495, 0.33343446,
#         0.36988397, 0.40633348, 0.44278299, 0.4792325 , 0.51568201,
#         0.55213151, 0.58858102, 0.62503053, 0.66148004, 0.69792955,
#         0.73437906, 0.77082857, 0.80727808, 0.84372759, 0.8801771 ,
#         0.91662661, 0.95307612, 0.98952563, 1.02597514, 1.06242465,
#         1.09887416, 1.13532367, 1.17177318, 1.20822269, 1.2446722 ,
#         1.28112171, 1.31757122, 1.35402073, 1.39047024, 1.42691974,
#         1.46336925, 1.49981876, 1.53626827, 1.57271778, 1.60916729,
#         1.6456168 , 1.68206631, 1.71851582, 1.75496533, 1.79141484,
#         1.82786435, 1.86431386, 1.90076337, 1.93721288, 1.97366239,
#         2.0101119 , 2.04656141, 2.08301092, 2.11946043, 2.15590994,
#         2.19235945, 2.22880896, 2.26525846, 2.30170797, 2.33815748,
#         2.37460699, 2.4110565 , 2.44750601, 2.48395552, 2.52040503,
#         2.55685454, 2.59330405, 2.62975356, 2.66620307, 2.70265258,
#         2.73910209, 2.7755516 , 2.81200111, 2.84845062, 2.88490013,
#         2.92134964, 2.95779915, 2.99424866, 3.03069817, 3.06714768,
#         3.10359719, 3.14004669, 3.1764962 , 3.21294571, 3.24939522,
#         3.28584473, 3.32229424, 3.35874375, 3.39519326, 3.43164277,
#         3.46809228, 3.50454179, 3.5409913 , 3.57744081, 3.61389032,
#         3.65033983]),
#  <BarContainer object of 100 artists>)
